# %%
# Impordid
import torch
from estnltk import Text
from estnltk.corpus_processing.parse_enc import parse_enc_file_iterator
from src.transformers import BertTokenizer, BertForMaskedLM, BertConfig, Trainer, TrainingArguments
import numpy as np
import os
from tqdm import tqdm

# %%
# Tokeniseerija
tokenizer = BertTokenizer(vocab_file = "vocab_final.txt", vocab_file_form = "vocab_form.txt")

# %%
# %%time
# Korpus
# Loeme tekstid sisse, laseme estnltk-l laused leida ning moodustame lausetest treening- ja testhulg
# https://github.com/estnltk/estnltk/blob/main/tutorials/corpus_processing/importing_text_objects_from_corpora.ipynb

input_folder = "korpus"
korpus = []

for filename in os.listdir(input_folder):
    file_path = os.path.join(input_folder, filename)

    n = 1 # Mitu teksti korpusesse lugeda
    l = 0
    for text_obj in parse_enc_file_iterator(file_path):
        korpus.append(text_obj)
        if l > n:
            break
        l += 1

train =  korpus[:int(0.6*len(korpus))]
val =  korpus[int(0.6*len(korpus)):int(0.8*len(korpus))]
test = korpus[int(0.8*len(korpus)):]

train_laused = []
for tekst in train:
    for span in tekst.original_sentences:
        train_laused.append(tekst.text[span.start:span.end])

val_laused = []
for tekst in val:
    for span in tekst.original_sentences:
        val_laused.append(tekst.text[span.start:span.end])

test_laused = []
for tekst in test:
    for span in tekst.original_sentences:
        test_laused.append(tekst.text[span.start:span.end])
# Out:
# CPU times: total: 9.75 s
# Wall time: 9.84 s

# %%
korpus
# Out:
# [Text(text='Tallinna linn algatab Paldiski maantee ääres Hotell Tallinna kõrval asuva suure vundamendiaugu ja tühermaa detailplaneeringu koostamise, ehitustööde alustamist takistavad aga ala segased omandisuhted. Piirkonnaarhitekt Alice Laanemägi ütles, et OÜ Maranello Vara on taotlenud linnalt selle ala detailplaneeringu koostamist, et ehitada sinna tulevikus Grand Hotel Tallinna laiendus, veepark ja parkla. Ehitisi planeeritakse kaks, korruseid 20 ja krundi täisehitamise protsendiks 80. Laanemägi lisas, et taotlus on küll olemas, kuid planeeringu koostamist ei ole veel jõutud alustada. OÜ Maranello Vara esindaja Olev Kasak ütles, et nad palusid küll linnal detailplaneering algatada, kuid võimalikust ehitamisest on veel ennatlik rääkida. Krundil on väga palju omanikke ja nende kõigiga tuleb ehitamise või maa ostmise üle läbi rääkida. Paraku ei ole firmal õnnestunud kõiki maaomanikke veel üles leida. AS Amerest Hotels kavatses sellele krundile 10 aastat tagasi ehitada Sheraton hotelli. 1992. aastal sai hoone ehitusloa ja 1993. aastal kaevati valmis vundamendiauk. Seejärel tekkisid ehitajal kohtuvaidlused ühe kinnistu õigusjärgse omanikuga ja kogu ehitus jäi seisma. Vundamendiauk on krundil siiani alles.'),
#  Text(text='Kaitseliit on saanud Tallinnas Viljandi maanteel asuva endise Liiva kõrtsi hoonestusõigusele seni kaks pakkumist, kuid kuulutuse hilinemise tõttu pikendas Kaitseliit konkursi tähtaega järgmise reedeni. Kaitseliit kuulutas 14. veebruaril välja konkursi Tallinnas Viljandi maantee 18 asuval endise Liiva kõrtsihoone kinnistul hoonestusõiguse seadmiseks 99 aastaks alghinnaga 750.000 krooni. Kinnistu suurus on 8745 ruutmeetrist, maa sihtotstarve on seni olnud riigikaitsemaa. Kinnistu territooriumi kasutatakse praegu küttepuude müügiplatsina. Kinnistul asub muinsuskaitsealune Liiva kõrtsihoone. Enampakkumiskonkursi läbiviija Argo Hollo ASist Kodu Haldus ütles, et praeguseks on tehtud kaks pakkumist, kuid konkursi tähtaja pikendamisega nädala võrra loodetakse pakkumisi saada veel. Konkursi tingimuste kohaselt peab hoonestaja püstitama uued ehitised ja renoveerima olemasolevad hooned kümne aasta jooksul. Samuti tuleb kinnistu hoida alaliselt heas seisukorras. Kui ehitamiskohustust ei täideta tähtajaks, peab hoonestaja tasuma 10.000 krooni kuu kohta.'),
#  Text(text='Eesti Fonogrammitootjate Ühing süüdistab valetamises Eesti Muusika- ja Fonogrammitootjate Liitu, kes väitis, et on muusikaauhinda Kuldne Plaat andnud välja juba alates 1998. aastast. Eesti Muusika- ja Fonogrammitootjate Liit (EMFL) teatas eile, et annavad aasta muusikaauhinda välja juba viiendat korda. Nii Kuldne Plaat 1998 kui ka Kuldne Plaat 1999 organiseeriti ja anti välja aga hoopis Eesti Fonogrammi Ühingu (EFÜ) poolt, teatas ühingu juhatuse esimees Aarne Valmis. Eesti Muusika- ja Fonogrammitootjate Liit asutati 6. veebruaril 2001 ning registreeriti Tallinna linnakohtu registriosakonnas 23. veebruaril 2001. Sellest lähtuvalt ei olnud neil mingil viisil võimalik korraldada 1998. ja 1999. aastal auhinnaüritust "Kuldne Plaat", lisas Valmis. EFÜ korraldab muusikaauhindade jagamist juba neljandat aastat. Kahel esimesel aastal välja jagatud popmuusika Kuldse Plaadi aastaauhindadest kasvas eelmisel aastal välja suurüritus "Eesti Muusikaauhinnad", mille raames tunnustatakse kogu eesti muusika paremikku. Põhjalikult muudeti võitjate väljaselgitamise tingimusi, kuna esimestel aastatel kehtinud põhiline kriteerium, läbimüüdud plaatide arv, ei vasta rahvusvaheliselt väljakujunenud ja tunnustatud standarditele. Alates eelmisest aastast selgitab muusikaauhindade nominendid ja võitjad 200liikmeline erapooletu, muusikavaldkonnas aktiivselt tegutsevatest isikutest koosnev žürii ning hääletustulemused kinnitab sõltumatu audiitor KPMG Estonia.'),
#  Text(text='Eetika eetikaks. Mõnes kohas on seda rohkem, teisal vähem. Parlamendis tavaliselt veelgi vähem. Ent asjal on ka põhiseaduse vastase tegevuse maik juures. PS § 75 : Riigikogu liikme tasu ning piirangud muu töötulu saamisel sätestab seadus, mida tohib muuta Riigikogu järgmise koosseisu kohta. Kavandatav eelnõu on põhiseadusega vastuolus, kuivõrd seda tahetakse rakendada sama koosseisu kohta. Keit Pentuse jutt, et põhiseadust võib rikkuda, kuna väljamakstav summa ei tõuse, on minu arvates "hülge möla". Õige ei ole väide, et väljamakstav summa ei tõuse. Siiani ei ole esitatud kuludokumente maksimumsummale (üksikud erandid väljaarvatud). Uue korra kohaselt makstaks maksimumsumma aga igal juhul välja. Teiseks ei saaks selget juriidilist keeldu õigustada väljamakstava summa suurusega (isegi kui see tõepoolest ei tõuseks).'),
#  Text(text='Riigikogu värske koosseis on juba enne, kui ta üldse õieti tõsiselt tööle hakata jõudis, raskelt haavata saanud. Isikkoosseis on küll täie tervise juures, kuid maine mitte. Postimees kuulutas üleeilse juhtkirja pealkirjaga ("101 mõttetut töökohta") sisuliselt kogu põhiseadusliku parlamentarismi tarbetuks. Vormiliselt on mõttetuks nimetatud küll 2011. aastast ehk alles järgmise riigikogu liikmetele kavandatavad isikliku abi kohad (muu maailma parlamentides üldlevinud praktika). Sisuliselt aga on nii, et kui parlamendi liige jäetakse ilma vajalikest töövahenditest või abistavast tööjõust, saab ta teha ainult pool tööd või vähemgi, tähendab - ongi mõttetu. Kuid seesama kehtib ju iga töö puhul. Assistentide, abide või nõuniketa ei saada hakkama väga paljudel juhtivatel kohtadel. Eriti nende tööde puhul, mille sisuks palju suhtlemist, avalikke esinemisi, koosolekuid jne, see tähendab, olukordi, kus ei saa vastata telefonikõnedele ega kirjadele, aidata hättasattunuid või lahendada ootamatuid kriise.'),
#  Text(text='Võimud võiksid oma keeldudes vähemasti erinevaid alkohoolseid jooke eristada, punane vein on teatavasti hoopis tervisele kasulik. Miks ei võiks müüa kvaliteetjooke ka hiljem? Paadunud joodik nii kui nii 700-kroonist konjakit ei ostaks. Kas on vaja odekolonnijoojate arvu kasvu ja uusi metanoolitragöödiaid? Ja veel : rohkem kui alkohol ohustavad eestlase tervist rasvase ja magusa söömine. Ehk seaks samuti vastavad piirangud?! Seni pole kuulda, et Harjumaaga piirnevate maakondade vanemad samuti alkoholimüügi keelu rakendamist plaaniksid. Seega hakkab teedel olema rohkem kahtlaselt liikuvaid autosid, mida juhivad joobes inimesed, kes naabermaakonda joogi järgi sõidavad. Kui aga keeld tuleb üle Eesti, hakkab piiriülene alkoturism - aprilli lõpu sündmused seda ju näitasid. Keeld tähendab ka seda, et inimesed hakkavad endale varuma koju suuremaid alkoholikoguseid nn. "igaks juhuks". Sellisel juhul ei pruugi inimene joomist lõpetada enne, kui kõik otsas. Sealjuures on tarbitavad alkoholikogused sageli suuremad. Lisaks sellele pole õhtusemal ajal paljud enam nii või naa suutelised täiendava noosi järele minema ning kui kodus parasjagu rohkem midagi võtta ei ole, siis vajuvad lihtsalt vaikselt ära.'),
#  Text(text='Paha pannakse tähele. Ammune rahvatarkus käib ka Jüri Jalaka kirja kohta (PM, 31. mai). Mitmed igati õiged mõtted ei pääse mõjule. Lugeja keskendub hoopis autori väljenduslaadile. See pole aga kaugeltki laitmatu. Mida üldse tähendab kooli konnatiigistumine? Konn ei saa ju roiskunud või mürgitatud vees elada. Milleks laskub arukas autor pehmelt öeldes küsitava väärtusega vaadetest innustunud tegelaste tasemele ning hakkab õhutama vihavaenu erinevatesse põlvkondadesse kuuluvate inimeste vahel? Mille alusel räägitakse vanematest õpetajatest kui pensionäride maffiast? Sõnavabaduse kuritarvitamine on kõikjal hukkamõistetav. Pedagoogilise töö eripära silmas pidades tuleb sedasorti demokraatiaavaldustele - just koolielu probleemide käsitlemisel - aga veel eriti teravalt reageerida. Vajame seadusesätteid, mis kodanike põhiõigusi (sõnavabadust) kärpimata võimaldaksid keerukate juriidiliste toiminguteta tõkestada sõnavabaduse kasutamist ebatervete meeleolude loomiseks ning niigi juba soovida jätva koolikorra laostamiseks.'),
#  Text(text='26. mai "Postimehes" kurdab Pille Villenthal, et Tartu eluruumide haldamise asutus nõudis temalt väljakirjutamisel õiendit, et korteril, kus ta elas, ei ole võlgnevusi. Sageli, kui meilt nõutakse selliseid õiendeid, oleme liiga tundlikud ja arvame, et just ametnik on see, kes peab meie kohta kõik välja uurima. Mul ei ole mingit alust kahelda, et kirja autor on kristalselt aus inimene ning temast ei jäänud maha mingeid võlgnevusi, kuid tuleb tunnistada, et Eestimaal on siiski tuhandeid inimesi, kellest jäävad lahkudes maha võlad. Juhul kui inimene lahkub võlgnevusi likvideerimata, jääb üle kaks teed. Kas panna võlad ülejäänud maksumaksjate kanda või palgata üks või mitu ametnikku, kes hakkaksid neid võlgnikke otsima. Ka nende ametnike palga, ruumide rendi, majandus-, sõidu- ja muud kulud kannavad maksumaksjad. Kirja autor tunneb rõõmu selle üle, et inimestel, kes mingil põhjusel taotlevad uut passi, ei tule uuesti esitada kodakondsust tõendavaid dokumente. Kuid Eestis on ka palju inimesi, kes on oma passi saanud ebaausal teel. Nende kindlakstegemise maksame samuti meie kinni. Kas on mõeldud sellele, kui palju see mugavusearmastus meie endi rahakotile maksma läheb?'),
#  Text(text='Kirjutan ühe päeva jooksul isiklikult Tallinnas kogetust. On kena, et ühissõidukites teadustatakse saabuvast peatusest. Ent tehnika viletsusest või juhtide individuaalsusest tingituna pole umbes pooltest nimedest võimalik aru saada. Väga tähelepanelikult jälgides, kui oled suutnud peatuses olevalt tahvlilt nime lugeda, võid aimata, et juht ütles samuti. Kuid lugemisega on tõsiseid raskusi, sest mõned nimed on osaliselt kustunud. Oli ka peatusi, kus polnud üldse midagi kirjutatud. Nii peabki tülitama alalisi sõitjaid, et mitte vales peatuses väljuda. Balti jaamas otsisin tükk aega Eesti Loto kioskit. lõpuks leidsin. Müüja ütles, et kunagi oli ka reklaam, kuid see võeti maha, sest ilmselt pole Eesti Loto vastavat maksu tasunud. Nii suure ja maineka firma puhul ei tohiks rahapuudus küll põhjuseks olla. Peaaegu iga posti küljes rippus tahvel tasulise infotelefoni 1188 reklaamiga. Sealt aga ei saa usaldusväärset teavet. Märtsi lõpus vahetati Läänemaal Uuemõisa algkooli number. Aprillis öeldi ikka veel vana number. Vaidlesin ja nõudsin uut, mulle vastati, et kasutusel on vana. Nüüd, mai lõpupoole, tegin jälle valearvestuse, usukudes, et nad ütlevad uue numbri. Huvitav, kas kuu aja pärast küsides saaksin uue numbri? See küsimus jääb vastuseta, sest Ekspress Hotline suutis õige numbri anda ja pealegi tasuta teenusena.'),
#  Text(text='TALLINN, 9. detsember (EPLO) - Riik lubab euro kasutuselevõtul ümardada riiklike maksude, tasude ja lõivude konverteerimisel summad ümardada maksumaksjale ja toetuse saajale soodsamas suunas. Selliste ümardamisreeglite järgimine jätab inimestele üle 130 miljoni krooni rohkem raha kätte. "Meie jaoks on väga oluline, et eurole üleminek toimuks rahva jaoks võimalikult sujuvalt. Kui on kuulda olnud kartusi, et euro kasutuselevõtuga võivad kaupmehed meelevaldselt hindu kõrgemaks ümardada, siis siin näitame ise kaupmeestele eeskuju - riik ümardab eelarvesse makstavad maksud ja riigilõivud ning eelarvest saadavad mitmesugused soodustused lähima täiseuroni maksumaksjale soodsamas suunas," ütles rahandusminister Taavi Veskimägi. Eesti eesmärk on olla tehniliselt valmis euro kasutuselevõtmiseks 2006. aasta jaanuari keskpaigast. Eelmise nädala reedel saatis rahandusministeerium arvamuste avaldamiseks välja eelnõu, mis sätestab juba enne euro kasutuselevõttu hindade avaldamise lisaks kroonidele paralleelselt ka eurodes. Rahaseaduse ja tarbijakaitseseaduse muutmise seaduse eelnõu eesmärgiks on anda aega tarbijal harjuda euro kui rahaühikuga ning vältida maksevahendi muutusega seotud hindade arvuliste suuruste muutusest tekkivaid võimalikke väärarusaame. Lisaks otsustas valitsus moodustada eurole sujuva ülemineku tagamiseks vajalike tegevuste koordineerimiseks ja ettevalmistamiseks asjatundjate komisjoni. Samuti otsustas valitsus edaspidi kord kvartalis valitsuskabineti nõupidamistel arutatada euro kasutuselevõtuga seotud teemasid.'),
#  Text(text='TALLINN, 9. detsember (EPLO) - Sideametil ei ole EMTile teenusepaketi Diil osas pretensioone, kuna Diil pole iseseisev juriidiline isik. EMTi, sideameti ja tarbijakaitseameti esindajad kohtusid neljapäeval, et arutada Diili temaatikat. EMTi turundusdirektor Piret Mürk ütles, et Diil on EMTi uus teenusepakett, nii nagu seda on juba varem turul pakutavad teenusepaketid Simpel ja POP. "Kuna Diil ei ole eraldiseisev juriidiline isik, siis pole sideametil pretensioone EMTi tegevusele," ütles sideameti peadirektori asetäitja Kaia Kulla. Tarbijakaitseamet jälgib, et teenusepaketti Diil ei reklaamitaks iseseisva operaatorina.'),
#  Text(text='TALLINN, 9. detsember (EPLO) - Neste langetas kell 15.00 bensiinide hindu 20 senti liitri kohta, hinnalanguse põhjuseks on bensiini sisseostuhindade langus kütuseturul. Futura 95 Euro maksab kõigis Neste A24 jaamades nüüd 11,10 ning bensiin Futura 98 Euro 11,80, vahendas Äripäev Online.'),
#  Text(text='Eesti Töörahva Kommuuni Nõukogu asjaajaja ja siseasjade komisjoni komissari kohusetäitja\n\nJohannes Käspert (vene keeles Кясперт Йоханнес Юрьевич) (9/21. mai 1886 Narva Peterburi kubermang Venemaa keisririik – 4. november 1937[1] NSV Liit) oli eesti poliitik, Eesti Töörahva Kommuuni Nõukogu asjaajaja ja siseasjade komisjoni komissari kohusetäitja (nn ajutine Siseasjade valitsuse juhataja)[2].\n\nJohannes Käspert sündis Narvas vabrikutöölise perekonnas, pärast Narva algkooli lõpetamist jätkas õpinguid ministeeriumikoolis. Pärast ministeeriumikooli lõpetamist asus 13-aastasena tööle Narva Kreenholmi vabrikusse jooksupoisina. 16-aastasena asus ta tööle Narva Zinovjevi metsatööstusettevõttesse noorema arveametnikuna ja hiljem edutati samas ettevõttes raamatupidaja abiks.\n\nJohannes Käspert hakkas osalema poliitilises tegevuses 1909. aastal, kui liitus Narva äriteenistusjate ametiühingusse, kus valiti ka ametiühingu juhatuse esimeheks. 1910. aastal oli Johannes Käspert üks Narva tööliste haridusseltsi asutajaid, ta ise juhendas seal esperanto keele ringi. Ta oli ka Narva Rahvahariduse Seltsi kirjatoimetaja ja hiljem esimees.\n\nJohannes Käspert oli koos Villem Bukiga bolševistliku Narva ajalehe Kiir asutaja ja toimetaja aastatel 1912–1914. Ta liitus Venemaa Sotsiaaldemokraatliku (bolševike) Parteiga 1912. aastal, 1913. aastal vahistati ta keisrivõimuvastase agitatsiooni eest ning viibis 7 nädalat eeluurimisvanglas, kuid vabastati süütõendite puudumise tõttu.\n\nEsimese maailmasõja alguses kolis Johannes Käspert Tallinnasse, kus asus tööle Fr. Krulli tehase haigekassa sekretärina ning tegeles ka bolševistliku agitatsiooniga, levitades sõja- ja keisrivõimuvastaseid lendlehti. 1914. aastal võttis ta osa VSDT(b)P Eestimaa konverentsi ettevalmistamisest, mis toimus Narvas 1914. aasta juulis, kuhu ta valiti ka konverentsi saadikuks.\n\n1916. aastal kevadel vahistati Käspert poliitilise tegevuse eest ning saadeti asumisele Turgai piirkonda, Kustanai maakonda, kust ta vabastati 1917. aastal veebruarirevolutsiooni tulemusel toimunud poliitilise amnestia alusel.\n\nJohannes Käspert oli Eestimaa Nõukogude Täitevkomitee liige, pärast Eestimaa Nõukogude Täitevkomitee poolt Venemaa Ajutise Valitsuse poolt määratud kubermangukomissari Jaan Poska võimult tõukamist oli Käspert Eestimaa Nõukogude ja Sõjaväelaste Nõukogu TK administratiivosakonna juhataja ja ajakirjanduse komissar[3]; Eestimaa Sõja-Revolutsioonikomitee (SRK), Revolutsiooniline Tribunali liige[4];\n\n1918. aasta märtsist töötas Johannes Käspert Nõukogude Venemaal ajalehe Pravda toimetuses; seejärel Vene SFNV Rahvuste Rahvakomissariaadis Eesti osakonnas ning Lipetski maakonna Täitevkomitees.\n\nTegevus 1918. aastal Eesti Töörahva Kommuunis[muuda | muuda lähteteksti]\n\n1918. aasta novembrist oli Johannes Käspert Narvas, Eesti Töörahva Kommuuni Nõukogu asjaajaja ja siseasjade komisjoni komissari kohusetäitja (nn ajutine Siseasjade valitsuse juhataja), ametisse määratud Viktor Kingissepa asemel, kes viibis illegaalselt Tallinnas.\n\n1919. aastast töötas Johannes Käspert luuretööl Punaarmee Staabis, Tšekaas ja OGPUs.\n\n1924. aasta veebruaris töötas ta NSV Liidu Ühendatud Riikliku Poliitvalitsuse Vastuluureosakonna 2. jaoskonna ülemana, Moskvas[5]; 2. jaoskond tegeles vastuluuretegevusega Eesti, Läti, Leedu, Soome, Rootsi, Norra ja Taani poolt NSV Liidu vastu suunatud luuretegevusele.\n\n1927. aastast parteitööl Petrogradis; 1930. aastast Kominterni Eesti sektsiooni sekretär Leningradis[7]/aastatel 1931–1937 oli Johannes Käspert Leningradis tegutsenud Kominterni Eesti Sektsiooni Leningradi Büroo sekretär.\n\nJohannes Käspert vahistati ja hukati NKVD poolt 1937. aastal, toimunud poliitiliste repressioonide käigus.\n\nRevolutsiooni tulevik on isikliku õnne alus, Aja Pulss, 1986, nr 9 lk 27–28\n\n↑Hea kommunist on surnud kommunist // Eesti Päevaleht, 22. september 2007\n\n↑Suur Oktoober või väike oktoober?, Eesti Päevaleht, 3. november 2007'),
#  Text(text='Praegune Kotzebue tänav oli Käsperti tänav. Andres 20. november 2010, kell 23:35 (EET)'),
#  Text(text='Johannes Elmar Kõdar (21. august 1900 Kuressaare – 14. november 1941 Sevurallag) oli Eesti diplomaat.'),
#  Text(text='Alkoholi ja sigarettide asemel võib juventekate sõltuvuseks pidada šokolaadi, sõpru, tööd, matkamist ja kaminatuld. Noorte põhimõtteks on mitte ohustada enda ja end ümbritsevate inimeste elu ning tervist.\n\nOrganisatsiooni presidendi Kai Krabo sõnul on demokraatia üheks Juvente alustalaks. Demokraatlik suhtlemine ja tegevus annavad kõigile (sh noortele) võimaluse end tõestada, end proovile panna ja ühiskonda paremaks luua. Karsked eluviisid aitavad sellele kõigele kaasa.\n\n"Kaine mõtlemine ja tegutsemine parandab elukeskkonda ning muudab ühiskonna tolerantsemaks ja demokraatlikumaks," toob Kai Krabo esile. Kõik see on Juventele tähtis, sest sõltuvust tekitavad ained pärsivad noorte organismi ning sallimatus ühiskonnas muudab meie elu. "Ole sina ise ja lase ka teistel olla nemad ise," sõnastab president Juvente suhtumise.\n\nJuvente on noor organisatsioon. Ühingu kaugeks eelkäijaks Eestis oli EHTO (Eesti Heade Templerite Organisatsiooni) kõrvale 1994. aastal asutatud EHTO noored. 1998. aastal ristisid viimased end ümber Juventeks. Päris iseseisvaks sai organisatsioon aga alles 2002. aasta aprillis.\n\nSõpru kogu maailmas\n\nToetust ning kaitset saab Juvente aga rahvusvahelise organisatsiooni EGTYF (European Good Templar Youth Federation) käest. Liikmeid on ühingul 20-30 vahel ning umbes 100 ringi ulatub organisatsiooni sõprade ring, kes tegevuste juures toetavad. Kai Krabo sõnutsi tulevad noored ise nende juurde, tikutulega noori karsklasi taga ei otsita.\n\nMTÜ Juvente president Kai Krabo peab eelkõige tähtsaks noorte teavitamist. "Me ei kuuluta, et alkohol on paha ja teeb sind haigeks, vaid propageerime, et karske eluviis on vahva, lõbus ja tervistav sinu kehale ja vaimule, " põhjendab ta.\n\nLisaks sellele arvab president, et raske on muuta täiskasvanud inimeste harjumusi, kuid kindlasti võimalik noorte suhtumist alkoholi, suitsetamise ja narkootikumide suhtes. "Kõige enam soovime muuta meie ühiskonna ja meie generatsiooni käitumist ja tarbimist, seda et noored mõtleksid enne, kui esimese mahvi tõmbavad ,või näpuga teistsuguse inimese poole osutavad," toob ta välja ühe Juvente soovidest.\n\nJuvente on oma arengu jooksul tegelenud paljuga, alustades "Halva maitse peost" ja postkaardiaktsioonidest tänavail, lõpetades seminaridega koolides ning üle-Eestilise fotokonkursi ja –näitusega. Kord paari nädala tagant saavad juventekad kokku ning mõtlevad üheskoos uusi ideid ja plaane välja. Mõned korrad aastas tehakse seda rahvusvahelisel tasandil Prahas, Kiievis või Strasbourg\'is teistest riikidest pärit Juvente noortega.\n\nKarsklus au sees\n\nLisaks kõigele muule on MTÜ Juvente oma viie tegevusaasta jooksul olnud seotud mitmete projektidega, millega üritatakse veelgi rohkem oma eesmärke teostada. Kai Krabo leiab,et eesmärkide saavutamine ei ole sugugi raske, kui toetamas on organisatsioon. "Meeskonna abil on kõik võimalik," arvab ta, lisades:" Eesmärk on seegi, kui projekt või üritus läheb korda; kui meie juurde tuleb noori, kes ühinevad meie organisatsiooniga. Tore, kui karskluse teema inimesi ei hirmuta. Kui nad on julged alkoholiprobleemi ühiskonnas tunnistama ning näitavad üles kodanikukohust, et midagi ise selles valdkonnas ette võtta."\n\nSeeõttu on organisatsioonil tähtis roll nii mõnegi noore elus. Kai Krabo ütleb, et Juvente annab enesekindlust, et võid olla selline nagu ise tahad. Ei pea kartma, kui tuttavate seltskonnas pitsist loobud – ei pea ole selline nagu on teised. Juventesse kuuluvad noored, kes ei vaja isiksust muundavaid aineid.\n\n"Juvente liikmed on kõik isesugused, kuid ikkagi moodustame sõpruskonna, sest me kõik aktsepteerime üksteist sellistena, nagu me oleme," on juventelasi kooshoidev pisike tõde.\n\nMTÜ Juvente\n\nMTÜ Juvente on 2002. aasta kevadel asutatud demokraatiat, tolerantsust ja karsket eluviisi toetav noorteorganisatsioon. Põhikirjas seisab, et ühingu tegevus tugineb muuhulgas üldisele inimlikule vendlusele, mille järgi on kõikidel isikutel õigus isiklikule vabadusele ja võimaluse ...
#  Text(text='Almanahhis on avaldatud arvukalt materjali Torma Maarja koguduse ajaloo kohta. Seal on kohaliku koduloouurija Ülo Pärniku põhjalik kirjutis "Tagasivaade Torma kiriku ja koguduse minevikku", ajaloolase Indrek Jürjo artikkel "Torma valgustuslik pastor Johann Georg Eisen", emeriitpraost Esra Rahula ülestähendused "Sada aastat peapiiskop Edgar Hargi sünnist" ja aastail 1964–1983 Torma kogudust teeninud õpetaja Jaan Muru mälestused Tormast lahkumise kohta pealkirjaga "Ligemale sihtkohale". Albumi toimetaja Rein Aro kirjutab: "Eesti keeles on ilus sõna – õpetaja –, millel on läbi aegade olnud kaks põhitähendust – kirikuõpetaja ja kooliõpetaja. Hea lugeja, oled juba märganud, et käesoleva "Torma Album" VI esikaanel on kirik ja tagakaanel kool, ja see ei ole juhuslik. Need sümbolid tähistavad selle väljaande põhiteemasid ehk kokkuvõtvalt – haridust." Almanahhi on võimalik osta Torma vallavalitsusest. Eesti Kirik'),
#  Text(text='Seadusemuudatusega muutub keskkonnatasu arvutuste esitamine, suureneb tasu maksjate vastutus ning tasude haldamisse kaasatakse lisaks Keskkonnaametile ka Maksu- ja Tolliamet.\n\nMuudatuse kohaselt maksab isik keskkonnatasu enda deklareeritud andmete alusel ning võrreldes varasemaga ei väljasta Keskkonnaamet enam tasu maksmise alusena makseteatist – nii keskkonnatasu arvutamine kui ka deklareerimine on keskkonnaloa omaja kohustus.\n\nAlates juulist saadetakse keskkonnatasu deklaratsioon hiljemalt aruandekvartalile järgneva kuu 25. kuupäevaks Keskkonnaametisse . Tasumisele kuuluva summa kannab keskkonnaloa omaja Maksu- ja Tolliameti ettemaksukontole. Keskkonnatasude arvestust hakatakse pidama samadel põhimõtetel nagu teiste riiklike maksude puhul.\n\nSeadusemuudatus puudutab saastetasude, vee erikasutusõiguse ja maavara kaevandamisõiguse tasu maksmise korraldust ning ei hõlma kalapüügiõiguse ja jahipiirkonna kasutusõiguse tasu maksmist.\n\nÜmberkorraldusega ei muudeta varem kehtestatud tasumäärasid ning keskkonnatasu maksjatele täiendavaid kulutusi ei tekitata. Ka tasu arvutamise alused ei muutu ning alusandmete kogumise põhimõtted jäävad samaks. Edaspidi muutub keskkonnatasu deklareerimine ettevõtetele mugavamaks, sest Keskkonnaametis valmib kliendile suunatud e-keskkond ja esimese teenusena pakutakse võimalust keskkonnatasu deklaratsiooni esitamiseks. Teavet e-teenuste portaali ja selle kasutustingimuste kohta ning vastavad juhendid leiab Keskkonnaameti kodulehelt alates maikuust.'),
#  Text(text='Ülestõusnud Meistrite tutvustus\n\nLeedi meister Nada\n\nLeedi Nada – kuuenda kiire chohan. Kiire värv on purpurne ja kuldne. See on rahu, teenimise ja abistamise kiir.\n\nChakra: päikesepõimik.\n\nSõna "Nada" tähendab vaikuse häält ja isiksuse kui isekuse kandja taandamist olematusse, tehes ruumi Kristus-minale.\n\nNada tuli kolmandalt (armastuse) kiirelt. Ta on üks nende hulgast, kes juhib inimkonna tervenemist. Praeguseks on temast saanud kuuenda kiire chohan. Ta õpetab isikliku Kristus-olemise teed läbi kogu elu teenimise, mis on jumaliku armastuse üks aspektidest.\n\nNada teenis Atlantisel preestrinnana Armastuse Templis. Tema sümboliks on roosa roos. Selle roosiõie mustri järgi kavandatud eeterliku templi asukoht on New Bedford ́i kohal Massachusettsis. Roosi iga õieleht kujutab üht ruumi. Keskel põleb Jumaliku Armastuse Leek, mida hoiavad põlevana kolmanda kiire vennad ja õed selleks, et tervendada armastuse abil planeet Maa evolutsioone.\n\nAtlantisel on Nada olnud seotud ka õigusteadusega. Jumalikele seadustele mediteerides mõistis ta, et seadus on kui kaitsevahend, mida Ema peab kasutama selleks, et kaitsta oma lapsi langenud teadvuse esindajate manipulatsioonide eest, kes samuti kasutavad sedasama seadust oma ebaõiglaste eesmärkide huvides.\n\nOma viimases kehastuses üle 2 700 aastat tagasi oli Nada noorim laps suures, erakordselt andekate lastega perekonnas. Peaingel Charity, komanda kiire peaingel, ilmus talle varases lapseeas ning õpetas, kuidas võimendada südames asuvat kolmekordset leeki ning kiirata seda oma andekate õdede-vendade tšakrate vibratsiooni tõstmisele kaasaaitamiseks. Ta loobus oma karjäärist selle nimel, et sügavas meditatsioonis olles hoida leeki oma õdede-vendade hüvanguks, et nemad suudaksid täita oma missiooni ja kunstide kaudu edendada kultuuri.\n\n28. augustil 1982 aastal antud diktaadis räägib Nada oma loo:\n\n"Kui ma olin kehastunud suures peres paljude õdede-vendade keskel, kes kõik olid väga andekad, nägin ma, et igaüks neist, pühendudes oma karjäärile, vajas armastust ja toetust ja salajase tule hoidmist selleks, et viia lõpule oma töö. Ja kuigi mul oli võimalus teha oma karjääri, hoidsin ma salajas, õdede-vendade teadmata nende jaoks vaikselt leeki, olles sügavas meditatsioonis ja palves.\n\nKaitstes oma vendade ja õdede Kristus-olemist, pidin ka mina edasi jõudma omaenda meisterlikkuses, et ületada langenud inglite vastupanu, kes tahtsid nurjata selle, mida oli mu vendadel-õdedel maailmale pakkuda. Nii mõistsin ma, et armastus on kui Püha Vaimu hävitav tuli, mis esitab väljakutse ja neelab teele ette jääva kuratliku.\n\nMa võin teile kinnitada, et oma kehastuse lõpus, kui ma nägin iga oma venna ja õe missiooni täitumist, oli minu rõõmu täiuseks teadmine, et armastuse leeki südames hoides mängis minu pühendumine nende saavutustes olulist osa.\n\nMaailmale ja ka mu perekonnale näis, et mina olin ainus selle pere lastest, kes polnud eriti midagi saavutanud. Kuid ma lahkusin kõrgematesse oktaavidesse põhjaliku arusaamisega roosa, armastuse leegi misterlikkuse tähendusest. Ma astusin Kristuse südamesse läbi kolmanda kiire ja nägin selle kiire rakendamise võimalikkust abistamisel ja teenimisel (kuues kiir)."\n\nSanat Kumara\n\nMa käin teie ees kogu teel Koju. Järgnege mulle.\n\nVaimne olevus nimega Sanat Kumara on tuntud ka nime all Iidsetest Aegadest (Ancient of Days). Ta on suur Guru, planeedil Veenus eksisteeriva tsivilisatsiooni hierarh. See tsivilisatsioon pole füüsilisel tasandil. Tema on meie initsiaator rubiinkiire teel.\n\nVäga pimedal ajal kauges minevikus maailma ajaloos, kus maailma evolutsioonide teadvus langes väga madalale tasandile, koopainimeste tasandile, kaotasid inimesed täielikult kontakti Jumala leegiga ja oma võimsa Mina Olen Kohalolekuga. See oli aeg, mil maailm jõudis punktini, kus oli kaalumisel tema püsimajäämine või hävimine, sest maa peal polnud enam ainsatki hinge, kes oleks suutnud hoida Kristus-teadvuse leeki elavana. Selles olukorras pakkus Sanat ...
#  Text(text='Riigikontroll saatis riigikogule kirja, milles süüdistab kaitseministeeriumi oma töö takistamises ning palub abi tüli lahendamisel.\n\nRiigikontrolli väitel ei saa nad oma tööd teha, sest kaitseministeerium ei lase neid ligi vajalikele dokumentidele. Kaitseministeerium omakorda kinnitab, et mingit kiusu ajamist pole, kuid riigikontrolli audiitoril pole salajaste dokumentide nägemiseks vajalikke lube. Tüli lahendab nüüd riigikogu erikomisjon, vahendas "Aktuaalne kaamera".\n\nKahe auväärse riigiameti tüli on pretsedenditu juhtum, sest seni on riigikontroll suutnud auditeerimise ette kerkivad tõrked kahe asutuse siseselt ära klaarida. Kaitseministeeriumis plaanitud mobilisatsioonivaru puudutava auditiga aga nii lihtsalt ei läinud. Nii kirjutaski riigikontrolör Mihkel Oviir riigikogule mureliku kirja, mille sisu on salajane, kuid pealkiri intrigeeriv.\n\n"Nagu riigikontrolör on oma kirjas öelnud, et parlamendi autoriteediga oleks võimalik edaspidi tagada riigikontrollile võimalus täita oma tööülesandeid," ütles riigikontrolli kommunikatsiooniteenistuse juhataja Toomas Mattson.\n\nRiigikontrolli kinnitusel on kaitseministeeriumilt nõutavad dokumendid mobilisatsioonivaru auditi tegemiseks äärmiselt vajalikud ja ilma nendega tutvumata pole auditi koostamine võimalik. Paraku on nõutavad dokumendid erineva salastatuse astmega.\n\n"Meie töötajatel, kes selle auditiga töötavad, on täielik õigus töötada riigisaladusega, kaitsepolitsei on neile väljastanud täiesti salajase tasemega riigisaladuse läbipääsu loa ja selle loa andmisega on see ühtlasi meie jaoks märk, et tegu on usaldusväärse inimesega, kelle tausta on kontrollitud," kinnitas Mattson.\n\nKaitseministeerium vaidleb vastu, et teatud dokumentidele ligipääsemiseks pole riigikontrollil vajalikke volitusi. NATO salajasi dokumente võivad lugeda vähesed ja nendele vähestele inimestele teeb taustauuringu kaitsepolitsei, kuid loa annab välja kaitseministeerium ise.\n\nKaitseministeeriumi õigus- ja kaitseküsimuste asekantsler Taimar Peterkop märkis, et kui riigikontroll teostab auditit, siis on tal õigus pääseda ligi vajalikele dokumentidele, kuid antud juhul on osa dokumentatsioonist Eesti riigisaladus ja osa on NATO salajane teave.\n\nPeterkop lükkas ümber väite, et kaitseministeerium on järk-järgult teatud dokumentidel salastatuse astet tõstnud.\n\nTüliõuna likvideerijaks peab seaduse kohaselt hakkama riigikogu riigieelarve kontrolli erikomisjon, kus siiani on riigikontrolöri kirja arutatud põgusalt.\n\nRiigikogu riigieelarve kontrolli erikomisjoni aseesimehe, reformierakondlase Tõnis Kõivu sõnul ei ole probleemi veel süvitsi arutatud. "Meil on olnud väga lühidalt juttu sellest, et ilmselt oleks kõige mõistlikum püüda läbi rääkida ja võimalikult konfliktivabalt kokkuleppele jõuda," nentis Kõiv.\n\nKaitseministeerium peab äärmiselt kahetsusväärseks, et seitse kuud kestnud vägikaikavedu on jõudnud avalikkuse ette.'),
#  Text(text='Ühisostu ajakava kohaselt peavad korteriühistud ühisostus osalemiseks saatma oma korterite tarbimisandmed 23. oktoobrist kuni 10. novembrini 2012, e-postiga aadressil:elektriost@ekyl.ee või aadressil: Sakala 23a, 10141, Tallinn.'),
#  Text(text='Raporti koostajate sõnum on, et kuigi kõik Lissaboni strateegia kolm sammast – majanduslik, sotsiaalne ja keskkonna alane – on jätkuvalt olulised, on Euroopa jaoks praegu esmatähtis suurendada majanduskasvu ja tööhõivet. Euroopa seisab vastamisi kahe suure väljakutsega – kasvav globaalne konkurentsivõime ja kiirelt vananev rahvastik . Kui Euroopa säilitab ja tugevdab oma majandus- ja sotsiaalmudelit, kohaneb ta uue olukorraga. Status quo ei ole lahendus.\n\nSuurema majanduskasvu ja tööhõive saavutamine nõuab pühendunud ja veendunud poliitilist juhtimist nii liikmesriikide kui Euroopa tasandil , millega peab kaasas käima Euroopa kodanike suurem kaasamine . Lissaboni strateegia eesmärkide saavutamisel on oluline tähtsus nende kommunikeerimisel ja aru saadavaks tegemisel.\n\nWim Koki raport teeb ettepaneku, et kõik liikmesriigid koostaksid Lissaboni strateegia eesmärkide täitmiseks riikliku programmi ja hakkaksid Euroopa Komisjonile selle täitmisest aru andma.\n\nRaport toob välja viis võtme poliitika valdkonda: teadmistepõhine ühiskond, siseturg, ettevõtluskliima, tööturg ja keskkonna hoid .\n\nTeadmistepõhise ühiskonna osas peab raport oluliseks tõsta Euroopa atraktiivsust rahvusvahelise taseme teadlaste jaoks, teadus- ja arendustegevuse (R & D) prioretiseerimist ja info- ja kommunikatsioonitehnoloogia kasutamise edendamist.\n\nSiseturu osas soovitab raport viia lõpule siseturu ülesehitus kaupade ja teenuste osas, eriti finantsteenuste osas.\n\nEttevõtluskliima koha pealt nimetatakse raportis vajadust vähendada administratiivseid koormisi ettevõtlusele, parandada seadusandluse kvaliteeti, soodustada uute ettevõtete kiiret ja kerget asutamist ning soodsa ettevõtluskeskkonna loomist.\n\nRaportis tõdetakse, et USA ja Jaapani kõrvale on tõusnud Euroopa konkurentideks globaalsel turul üha rohkem kvaliteetsemat kaupa tootev Hiina ja teenuste turul kanda kinnitav India , kus on palju haritud, odavat ja inglise keelt rääkivat tööjõudu.\n\nProbleemiks Euroopas on ka pidurdunud tootlikkuse kasv , mis tuleneb vähestest investeeringutest töötajatesse ja tehnoloogia arengu aeglustumisest. Euroopa majanduse struktuur toetub pigem madalale või keskmisele tehnoloogiale, mitte kõrgtehnoloogiale. Kui USAs on tööhõive kasv seotud ka töötunni tootlikkuse kasvuga, siis Euroopas on tööhõive kasv seotud töötunni tootlikkuse langusega. Uued loodud töökohad Euroopas on madala tootlikkusega.\n\nEuroopa tööturgude paindlikumaks muutmisel ei näe raporti koostajad töötajate õiguste või kaitstuse vähenemist. Pigem tähendab see kõrgemat tööhõivelisust (employability) ja konkurentsivõimet ning võimalust liikuda kiirelt ja kergelt ühelt töölt teisele. Paindlikkust peab toetama vastav sotsiaal- ja elu kestva õppe süsteem, mis võimaldab oskuste pidevat uuendamist. Selliste muutuste ellu viimiseks on oluline sotsiaaldialoog.\n\nKeskkonna säästlikkuse osas paneb raport ette stimuleerida öko-innovatsiooni ja tootlikkuse saavutamist läbi öko-efektiivsuse . Ühe poliitilise meetodina soovitatakse ka "rohelisi" riigihankeid.\n\nRaporti koostas kõrgetasemeline ja rahvusvahelistest ekspertidest koosnev töörühm Euroopa Komisjoni tellimusel, eesmärgiga saada sõltumatu ülevaade Lissaboni strateegia elluviimise käigust. 2000. a. vastu võetud Lissaboni strateegia seab eesmärgiks muuta Euroopa kõige dünaamilisemaks ja konkurentsivõimelisemaks teadmistepõhiseks majandusregiooniks maailmas 2010. aastaks koos jätkusuutliku majanduskasvu, rohkemate ja paremate töökohtadega, suurema sotsiaalse kaasatuse ja keskkonna hoiuga.\n\nRaporti lisas riikide kaupa avaldatud tööhõive ülevaates on Eesti kohta märgitud, et tööhõive määr on meil pisut alla EL keskmise. Töötuse määr on mitme aasta jooksul langenud, kuid pikaajaliste töötute osakaal on ikka kõrge. Eesti on üks neist Euroopa riikidest, keda demograafilised muutused kõige enam mõjutavad ja kus tööealise elanikkonna osa kõige olulisemalt väheneb.\n\nTööjõu maksukiilu vähendamine, eriti madalapalgaliste osas, ning erinevat ...
#  Text(text='Veterinaarkontroll kauplemisel\n\nKauplemisena käsitletakse Eesti ja Euroopa Liidu liikmesriikide vaheline kaubandust. Kauplemisel tehakse veterinaarkontrolli reeglina kauba lähte- ja sihtkohas, kuid kontrolli teostamine on lubatud ka veo käigus. Eestisse läbi piiripunkti toodaval liikmesriigist pärineva kauba korral kontrollitakse kauba saatedokumente.\n\nLoomade ja loomsete saadustega kauplemisel sihtkohas ja piiripunktis tehtava veterinaarkontrolli kord, samuti nõuded inimese või looma tervisele ohtlikuks või muul põhjusel mittenõuetekohaseks osutunud loomade ja loomsete saaduste edasiseks käitlemiseks ning mittenõuetekohasuse avastamise korral rakendatavad meetmed kehtestatakse põllumajandusministri 7. mai 2004. a määrusega nr 85 "Sihtkohas ja piiripunktis tehtava veterinaarkontrolli kord" .\n\nVeterinaarkontroll importimisel\n\nImpordi all käsitatakse loomade ja loomsete saaduste toimetamist ühendusevälisest riigist Euroopa Liidu territooriumile vabasse ringlusse lubamiseks, toimetamist ühest ühendusevälisest riigist samasse või teise ühendusevälisesse riiki läbi Euroopa Liidu territooriumi (transiit), toimetamist ühendusevälisest riigist Euroopa Liidu territooriumil asuvasse vabatsooni, vabalattu või tollilattu või toimetamist ühendusevälisest riigist Euroopa Liidu territooriumile muul eesmärgil.\n\nImporditavat kaupa kontrollitakse piiripunktis. Külmutatud ja sügavkülmutatud tuunikala, millel pea ja siseelundid on eraldamata, nõuetekohasust võib kontrollida kaubasaadetise sihtkoha ettevõttes ja selleks on seaduses esitatud eritingimused.\n\nLemmikloomade suhtes, keda tuuakse ühendusevälisest riigist, kohaldatakse Euroopa Parlamendi ja EL Nõukogu määrust 998/2003/EÜ, millega kehtestatakse nõuded looma tervisele lemmikloomade mittekaubanduslikul eesmärgil liikumisel (ELT L 146, 13.06.2003, lk 1–9). Järelevalve teostajaks on Maksu- ja Tolliamet.\n\n"Loomade ja loomsete saadustega kauplemise ning nende impordi ja ekspordi veterinaarjärelevalve seaduse"§ 18 lõike 7 kohaselt nende loomade ja loomsete saaduste, mille kohta ei ole kehtestatud veterinaarnõudeid, kohta otsustab Veterinaar- ja Toiduamet vajaduse esitada veterinaarnõuete kohasuse tõendamiseks sertifikaat ning koostab eelneva riskianalüüsi tulemuste alusel nõuded veterinaarnõuete kohasuse tõendamiseks. Määrusega on kehtestatud sellisel sertifikaadil esitatavate andmete loetelu.'),
#  Text(text='See romaan alustab "Kuu ordu" eellugu. Aastal 2061 on Kuu ordu alustanud lähikosmose hõivamist... nende kontrolli all on ka Madagaskar. Keelatud tehnoloogiaid arendav ja igasugustele seadustele sülitav salaühing on muidugi pinnuks silmas maistele suurvõimudele. Nii kirjeldabki romaan sündmusi, mis viivad järjest lähemale USA ja India ühendatud armeede sõjakäigule Kuu ordu vastu. (Pealkiri, muide, on ikka ehtne lausemonstrum-miks mitte "Sõjaeelne kullakarva"?-ent ju see siis oli taotluslik).\n\nRomaan on nii tüüpiline Veskimehe tekst, kui vähegi olla saab, autorile omaste plusside ja miinustega. Need, kellele Veskimehe stiil ei meeldi, võiksid teosest küll eemale hoida. Siit ka üks etteheiteid-erinevalt näiteks Harglast ja Tarlapist kirjutab Veskimees täpselt samamoodi, nagu kümme aastat tagasi.\n\nAutori tugevaks küljeks on tema ideed ehk siis täpsemalt tänapäeva ühiskonna vaimsele kopitusele vastanduv mässuline tulevikunägemus, samuti seikluslik sündmustik. Veskimees on üks neid autoreid, kelle tekstid muudab rohke märul paremaks-dialooge ega psühholoogiat ei kanna ta hästi välja. "Ennesõjaaegse kullakarva" miinuseks alguses ja keskpaigas ongi tegevuse liigne lohisemine, mistõttu hinne kaldus minu silmis vahepeal isegi "kolme" kanti... Lõpuks venitas küll nelja välja.\n\nSuurimaks miinuseks vast see, et ehkki romaani tegelaste hulgas on muuhulgas eestlasi, sakslasi, jaapanlasi, ameeriklasi ja Madagaskaril elavaid prantsuse kolonistide järeltulijaid, on neid käitumise ning dialoogi järgi võimatu üksteisest eristada. Prantslase tunnuseks on prantsuskeelne vandumine, ent see on ka kõik. Tegelased käituvad ja räägivad täiesti ühtmoodi, neil puudub isikupära, mis paneks kaasa elama. Oskust karaktereid luua peaks Veskimees veel kõvasti harjutama.\n\nVeskimehe opus on tehniliste detailide kirjeldamisel täiesti pädev, aga inimesed ja ühiskond. No vabandage väga! Kõige hullemad on inimeste vahelised suhted ja seks. Sellel pole mitte mingit seost reaalsusega. See on mingi teismelise teaduspreemia laureaadist nohiku erootiline unistus. Naised kõik on eranditult, lausa silmi pimestavad, raha pakkumise peale kõik nad siiralt imestavad, kui tsiteerida punkbändi Müstika. Veskimehe maailmas on naised kõik ilusad ja heas vormis ja niipea kui nad vabanevad "poliitkorrketsuse kammitsast" kukuvad nad valimatult keppima kõigega, mis liigub. Hallooo, teate, reaalses maailmas on inimestel ikka mingid tunded ka üldjuhul. Nagu mingid teismelise koolipoisi pihkurifantaasiad. Lisaks saab nohikust tuumateadlasest Kuu Orduga liitumisel üleöö järsku alfaisane, kes vasaku käega neegergängstereid notib ja keda ülalmainitud nümfomaanid karjade kaupa piiravad. Ja mitte niisama, alfaisane vaid alfaisane teiste alfaisaste seas. Vot selline tore värk: käik on alfad, üks isasem kui teine. Ja ei mingeid konflikte? Mitte mingit võimuvõitlust? Ühesõnaga, Veskimehe kommunism on kohati kommunistlikum kui Strugatskite tulevikühiskond. Kuigi see tundub võimatu, suudab Veskimees konstrueerida veel usutamatumaid ühiskondi ja sotsiaalseid formatsioone, kui Heinlein.\n\n.. Kullakarva, kõige ehedam Veskimees koos kõige sellega mida olen harjunud tema raamatutes lugema ja jumal tänatud. Eelpool olevates arvustustes on mainitud et kirjanik pole kulunud aastatega midagi õppinud ega oma stiilis muutnud.. mina selel üle ei kurda, vastupidi.. see stiil mida Veskimees viljeleb ongi see mis paneb mind tema raamatuid lugema ja virin teemal, et loodud ühiskond pole reaalne või naised liiga lõdva kummiga.. no vabandust kui ma tahan kellegi reaalelust tehtud tõmmiseid lugeda siis ma ilmselt ulmeraamatut kätte ei võta. Seega ..loodud maailm on ühele toredale ulmekale igati asjakohane ja olen kirjanikuga ühte meelt (mõningate arvates siis sama perversne) et selles maailmas tahaksin ka ise elada. Plussid: Veskimehe luulud tema parimas vormis.. loodud maailm, tegelased, tehnika ja väike psüholoogiline vint selle kõige seljas. Miinused: Veskimees on uue raamatuga siiski midagi õp ...
#  Text(text='Alates 1. jaanuarist 2011. a algatatavatele hangetele rakendub RHS § 41 lg 3 järgmises sõnastuses: "Kui hankelepingu alusel sooritatava tegevuse jaoks on õigusaktides kehtestatud erinõuded, nimetab hankija hanketeates, milliste erinõuete, registreeringute või tegevuslubade olemasolu on pakkuja või taotleja kvalifitseerimiseks nõutavad./.../".\n\nSeega lähevad nn uute hangete puhul pakkujate või taotlejate kvalifitseerimisel arvesse ainult need eriseadustest tulenevad nõuded, mille hankija on hanketeatesse otsesõnu märkinud. Sätte muudatuse mõte on suunata hankijaid põhjalikumalt ja adekvaatsemalt hankemenetlusi planeerima, et kõikide sõlmitava hankelepingu esemeks olevate tööde teostamise pädevuse (õiguse) olemasoluks vajalikud erinõuded oleksid loetletud juba hanketeates. Eelduslikult tunneb just hankija kõige paremini sõlmitava hankelepingu esemeks olevate tööde sisu ja mahtu.\n\nAllakirjutanu hinnangul ei pruugi sellise muudatuse puhul tingimata olla tegemist "oodatud päästepaadiga", vaid võib tuua kaasa hankija algatusel hankemenetluste kehtetuks tunnistamiste arvu suurenemise. Seejuures väärib rõhutamist, et RHS § 41 lg 3 ettevalmistamisel on eelnõu seletuskirja märgitud, et juhul, kui hankija on jätnud hanketeatesse mõne erinõude märkimata, kuigi seda on tarvis hankelepingu eset arvestades, siis võib see tähendada, et hankija peab omal algatusel hankemenetluse kehtetuks tunnistama.\n\nKui enne 1. jaanuarit 2011. a alustatud hankemenetlustega oli võimalik edasi minna ja hankelepinguni jõuda olukorras, kus kvalifitseerimisotsuste vaidlustamise tulemusena on saanud selgeks, et hankelepingu esemeks olevate tööde teostamiseks on täiendavalt tarvis kontrollida veel ühte või teist eriseadusest tulenevat tegevusluba, registreeringut vms, siis nüüd paistab olukord olevat muutunud pigem segasemaks.\n\nNimelt laieneb esiteks vaidlustamisest huvitatud isikute ring. Kui seni esitasid eriseadusest tuleneva kvalifitseerimisnõude mittetäitmise põhjendusel vaidlustuse pakkujate kvalifitseerimise otsuste peale orienteeruvalt kaks-kolm madalama maksumusega pakkumuse esitanud pakkujat, siis nüüd on põhjust ja huvi kõikidel turul tegutsevatel vastava valdkonna ettevõtjatel, kes kavatsevad konkreetses hankes pakkumust esitada, esitada vaidlustus hanketeates sätestatud tegevuslubade jms nõuete loetelu peale põhjusel, et loetelu ei ole ammendav. Huvi selleks võib muu hulgas seisneda selles, et saavutada spetsiifilise tegevusloa nõude hanketeatesse lisamine, mis ahendab oluliselt riigihankes osalevate konkurentide ringi ning mida ei ole võimalik konkurentidel kiiresti omandada.\n\nTeiseks võib juhul, kui pakkumuste esitamise tähtpäeva möödumise järel selgub, et mõni erinõue jäi hanketeatesse lisamata, hankijal tekkida põhjendatud vajadus tunnistada hankemenetlus omal algatusel kehtetuks, sest tal ei ole võimalik jõuda hankelepingusse vastava hanke tulemusena nii, et kõik hankelepingu esemeks olevad tööd ka reaalselt teostatakse. Võib tekkida olukord, kus hiljem peaks hakkama korraldama eraldi hankemenetlusi nn pisitööde peale, mis kuulusid algse hankelepingu esemesse, kuid mille kohta seadusest tulenevat erinõuet hankija hanketeatesse ei lisanud. Siinkohal tuleb arvestada, et juba algses hankes on pakkumuse koostamisel (hinnaesildisel) pakkuja suure tõenäosusega arvestanud ka selle töö tegemisega, mille kohta hankija unustas hanketeates erinõude sätestada, kuigi vajadus reaalseks tegemiseks tuleb hankelepingu esemest. Selle tulemusena maksab hankija ühe ja sama töö eest kaks korda.\n\nAgris Peedu sõnul sai § 41 lg 3 oma lõpliku sõnastuse alles Riigikogu majanduskomisjonis ning sealseid muudatusi/täpsustusi ei kajastata enam eelnõu seletuskirjas, mis on eelneva artikli aluseks.\n\nRiigihangete seaduse § 41 lg 3 sätestab, et kui hankelepingu alusel sooritatava tegevuse jaoks on õigusaktides kehtestatud erinõuded, nimetab hankija hanketeates, milliste erinõuete, registreeringute või tegevuslubade olemasolu on pakkuja või taotleja kvalif ...
#  Text(text='Noorte tantsupidu\n\n1962. aastal toimus I Koolinoorte Tantsupidu , mille idee autor ja eestvedaja oli Alfred Raadik . Edaspidi toimusid noorte tantsupeod iga viie aasta tagant järgnevalt: II (1967), III (1972), IV (1977).\n\nV Noorte Tantsupeo (1982) üldjuht-stsenarist Mait Agu pakkus uudse nähtusena välja kogu pidu läbiva ühtse teema . Selleks keskseks teljeks sai üks päev koolilapse elust. Antud peol oli ka suurem osatähtsus liikumis-rühmadel (võimlemisrühmad erinevate tegevustega). Võimlemisrühmade üldjuhiks oli Liia Palmse. Peo aujuhiks paluti Alfred Raadik.\n\nVI (1987) Noorte Tantspeo üldjuht oli Mait Agu, VII (1993) oma Ilma Adamson. VIII (1998) koduteemalise peo üldjuhiks oli taas Mait Agu.'),
#  Text(text='AS Fujitsu Services tegutseb lisaks kohalikule turule ka väljaspool Eestit, omades kliente Inglismaal ja Skandinaaviamaades. "Osutame teenuseid võrdsel määral kodu- ja välisturgudel, panustades aktiivselt tegevuse laiendamisse mõlemal rindel," lausus Järviste.\n\n2007. aastal oli ühinenud ettevõtete liidetud käive 78,7 miljonit krooni. Käesoleva, 2008. aasta käibeks planeerib AS Fujitsu Services 100 miljonit krooni. Ühinenud ettevõttel on esindused Tallinnas ja Tartus, kus kokku töötab 160 inimest. "Koostöös Fujitsu Services Ltd Läti ja Leedu esindustega avaneb meil võimalus pakkuda kõiki teenuseid pan-Balti turul," mainis Järviste.\n\nÜhinenud ettevõtted, mis mõlemad omavad 17- aastast IT teenuste arendamise kogemust, on välja kasvanud Küberneetika Instituudist, mille erinevate osakondade põhjal loodi kaks IT ja elektroonikaga tihedalt seotud ettevõtet Assert (1992) ja Systest Plus (1992). Assert alustas turul IT riistvara toodete müügi ja tarkvara arendusteenustega. Alates aastast 2007 AS Mandator Estonia nime kandud firma on keskendunud tarkvara arendusteenustele. Systest Plus on asutamisest saadik pakkunud IT remondi- ja hooldusteenuseid Fujitsu kontsernile, kandes alates 2003. aastast nime Fujitsu Services OÜ.\n\nFujitsu Services Ltd omandas enam kui 500 töötajaga Rootsi päritolu Mandator AB aktsiapaki läbi avaliku ostupakkumise 2007. aasta detsembris.\n\nFujitsu Services Ltd kuulub ülemaailmsesse Fujitsu kontserni, mis üle 160 000 töötajaga ja esindatusega enam kui 70 riigis on üks maailma juhtivaid IT korporatsioone. 31. märtsil 2008 lõppenud majandusaastal oli grupi kogukäive 53 miljardit USD.'),
# ...
#  Text(text='Vallavanem: vallajuhid võiksid priitahtliku päästjana eeskuju näidata\n\nHiiumaal asuva Kõrgessaare vallavanem Jaanus Valk peab mõistlikuks, et vallajuhid oleksid seotud priitahtliku päästetööga ja sel viisil eeskuju näitaksid.\n\nSiseminister Ken-Marti Vaher soovitas eile päästeameti konverentsil vallajuhtidele hakata priitahtlikeks päästjateks, et seeläbi näidata eeskuju ja tuua vabatahtlikkusse päästetegevusse rohkem inimesi.\n\n"Ma arvan, et igal juhul võiksid vallajuhid eeskuju näidata. Kui selline asi kah kogukonda ei puuduta, siis keda ta veel puudutab?" sõnas Valk. "Eriti nendes piirkondades, kus riik kipub natuke kaugeks jääma."\n\nValk on ise priitatahtlik päästja juba 1987. aastast. Ta ei osanud öelda, kui levinud see on, et vallajuhid kuuluvad priitahtlike päästjate hulka, kuid ütles, et paljud vallad on Priitahtliku Päästeliidu liikmed.\n\nValk rääkis, et Kõrgessaare vabatahtlik komando keskendub peamiselt maismaa tuleteenusele, kuid tegeleb vajadusel ka merepäästega. Nimekirjas on 15 vabatahtlikku, kellest praeguseks on koolitatud 8 ning 3 on kutselised.\n\n"Täna on olukord selline, et Kõrgessaare piirkonnas kutsutakse sündmusele kohe ka vabatahtlik komando," rääkis Valk, kelle sõnul on neil on riikliku komandoga hea koostöö. Ta nentis, et päästeautod on küll vanad, aga see on üldine probleem.\n\nValgu sõnul võiks riik hakata priitahtliku pääste juures toetama sellist teenust, et üks mees saaks olla kohapeal valves.\n\n"Täna on meil kodu- või töövalve, aga et üks mees saaks tehnikaga välja tulla ja teised mehed tuleksid järgi, võiks ühe mehe palgafondi siiski luua," pakkus ta.\n\nMida peaks tegema, et vabatahtlikud komandod tekiksid ka sinna, kus neid praegu pole?\n\n"Kui mehed ei saa aru, et oma vara on oma vara ja ise tuleb kaitsta oma kodu ja kogukonda, siis ei oska mina öelda, kuidas seda selgeks teha," vastas Valk.\n\nSeoses 9 riikliku päästekomando sulgemisega, on oma töö lõpetanud ka Emmaste komando Hiiumaal. Kuigi väljakutseid polnud palju ja päästjad samuti mitte, oli sel komandol Valgu sõnul oma roll.\n\n"Katmata jäi Lääne-Hiiumaa. Elupäästevõimekust tal ei olnud, aga neid sündmuseid saab ühe käe sõrmedel üles lugeda, kui sellist vajadust on olnud," lausus Valk. Ka Emmastesse on tekkimas vabatahtlik komando.'),
#  Text(text='Viis paksupeksulauset, mis esmapilgul ei näi solvavad\n\nPaksupeks on täiesti reaalne nähtus – ühiskond ütleb kogukamatele inimestele pidevalt, et nad on koledad, inetud ja vääritud. Asi on selles, et paksupeks ei toimi. See ei aita inimestel kaalu kaotada, vaid teeb nad õnnetuks ning halvimal juhul on suisa tervisele kahjulik.\n\nNiisiis oleks kena, kui kõik me püüaksime üksteise suhtes lahkemad ja viisakamad olla, et maailm oleks meile kõigile parem koht elamiseks. Panime Bustle\'i abiga kokku mõned laused, mis esmapilgul võivad kõlada toetavalt ja mittesolvavalt, kuid tegelikult on häbistavad ja mõnitavad.\n\n"Sa pole paks! Sa oled ilus!" Tegemist on väga problemaatilise lausega, sest see kinnistab arvamust, et paksus ja ilu on asjad, mis välistavad teineteist. Tegelikult võivad inimesed vabalt olla paksud ja ilusad.\n\n"Ära ütle enda kohta paks. Ära räägi enda kohta nii!" Paljud inimesed kasutavad sõna paks solvanguna, see-eest väga paljud inimesed on aru saanud, et tegemist on vaid omadussõnaga, mis iseenesest ei tohiks kanda mingit alltähendust, ning püüavad seda jõustavalt kasutada. Sa ju ei saa vihaseks, et su kahemeetrine sõber enda kohta pikk ütleb? Lase inimestel iseloomustada end (armastavalt) nende sõnadega, mis nad soovivad.\n\n"Õh, ma olen nii-ii paks!" Jah, me just ütlesime, et peaks olema okei, kui inimesed enda kohta paks ütlevad. Seda juhul, kui nad on tegelikult paksud. Kui sale inimene, kes pole iialgi tundnud, mis tähendab tänapäeva ühiskonnas paks olla, otsustab, et ka tema võib seda sõna enda kohta kasutada, võtab see sõnalt jõu. Kui sul on kõht täis või parasjagu tunned, et su keha võtab rohkem ruumi kui tavaliselt, siis ütle nii. Ära naeruväärista pakse kehasid ja ära kasuta selle sõna negatiivseid konnotatsioone lihtsalt selleks, et komplimente norida. Meil kõigil on aeg-ajalt oma kehadega probleeme, aga katsu olla realistlik.\n\n"Sul on nii ilus nägu!" Jällegi tundub lausena, mis oleks justkui kompliment. Tegelikult on tõenäoliselt tegemist mikroagressiooniga kõigi paksude inimeste vastu. Paksud on harjunud kuulma komplimente oma näo kohta. Käsi püsti, kellele on kunagi öeldud: "Sa võiksid olla imeilus, kui ainult kaotaksid mõned kilod!" Minu personaalne lemmik kunagiselt poiss-sõbralt kõlas nii: "Nägu on sul modelli oma, aga..." No tore küll, et mu nägu on ilus, aga ülejäänud osa minust ei kõlba?\n\n"Oi, sul on see seljas? Sa oled nii vapper!" Me ju teame, et inimesed arvustavad ja mõnitavad teisi pidevalt selle põhjal, mis neil parasjagu seljas on. Kogu aeg. On tõenäoline, et kui su sõber otsustas selga tõmmata minikleidi, siis ta juba kaalus, kuidas tema riietumisakt ühiskonnanormidele vastu astub – ja ta otsustas seda ikkagi teha. Niisiis, ütle lihtsalt, et ta riietus on nunnu ja jäta see nii. Asi on selles, et tegelikult ei peaks ükski rõivastumise akt olema vaprus omaette.\n\nMe keegi ei taha oma sõpradele – ka paksudele sõpradele – oma sõnadega liiga teha. Kindlasti aeg-ajalt juhtub, et me eksime ning ütleme midagi, mida võiks liigitada paksude häbistamise alla. Kui sa märkad end olevat eksinud, siis vabanda ja liigu edasi. Ikka juhtub. Aga ära unusta vabandada!'),
#  Text(text='neljapäev, detsember 31\n\nAastalõpu puhul juuakse ohvissis shampust.Mehepojad Maurits ja Boss loobivad omavahel shampusepudeli korki. Eelnevalt on juttu olnud kaaskondsete sportlikest saavutustest. Noh ikka medalid ja aukirjad ja diplomid ja värki...Õrne kommenteerib:"Osavad mehed olete"Boss:"Ja-jah meil on korvpallis ju medalid kah!"\n\nneljapäev, detsember 24\n\nEnne kui töörahvas maakodudesse laiali läks, toimus väikestviisi jõululõuna ka kontori tingimustes. Naised tegid suia, mehed olid külmarohuks toonud tundmatute ürdimeistrite poolt valmistatud likööri. Kohe peale suitsutesti leiti, et see jook ei ole ikka see. Aeg lendas. Tehti nalja, kadusid küpsetised, mandariinid... vaikselt-vaikselt vähenes ka külmarohi.Ja kui ürituse lõpuks, kasutades kõrvaltubade abikäsi(kõri), paistis läbi ka pudel, võttis Õnnelemb teema kokku prohvetlike sõnadega:"Kaua olen otsinud oma lemmik likööri..."\n\nteisipäev, detsember 22\n\nMaurits ja Susi-Pärje arutavad asju msnis. Viimane annab teada, et tuleb kohe Mauritsa tuppa teed tegema. Lähebki siis. Aga valib vee võtmiskohaks hoopis kohvimasina, mitte ei täida veekeedukannu ja pane seda käima.Ilmselgelt neiu valikutes pettunud Maurits:"Äh! Sellega teedki vä?"Susi-Pärje:"Mhmh.. Siit saab ju kohe joodavat vett mitte kuuma. "Maurits tõuseb püsti ja lohistab ennast ise veekannu juurde nuppu vajutama.Susi-Pärje:"Noh? Pettusid mu\'s nüüd jah?"Maurits:"Jah! Nüüd sa hüppasid küll lati alt läbi!"\n\nesmaspäev, detsember 21\n\nEsmaspäeva hommik.Kell 8:30. Tegevuspaik: KontorLaekub Pr.Kunn, liigub oma laua taha:"Kurat! Arvuti jäi koju. Ma tulen 20min pärast uuesti" ... ja sinna ta kadus.\n\nKell 8:45. Tegevuspaik: Kunni kodu.Kuulda on ukse lahti keeramist ja seejärel pr.Kunni häält:"Üks väga tige naine võtab oma arvuti!" Ja uks sulgub.\n\nOlukorda kommenteerib kodutööpäeval olev Kunn:"Ma ei jõudnud ahah ka öelda."\n\nreede, detsember 18\n\nÕrne suunati äsja ühe uue projekti peale asjapulgaks. Boss käis selle projekti ärikliendiga sõbralikku juttu vestmas, et mis see tulevik toob jne. Pärast tagasitulles pajatas Õrnele õhinal: Boss:"Ärikliendil läksid sinu peale silmad särama. Et ta näeb kuidas sa juba härjal sarvist haarad ja tegutsed. See erutab teda!" Iivl lafter tagareas ja Õrne karjatab: "Sa oled rõve!"\n\nteisipäev, detsember 15\n\nPr.Kunn on naasenud meie tublisse ohvissi kollektiivi. Kuna eemal oldi mõned aastad, saab ta varustuseks võrreldes varasemaga silmnähtavalt moodsamad tehnilised abivahendid.Teebki teine tutvust oma töölaua ja raaliga:"Nii suur monitor! Nagu lennujuhtimiskeskus kohe."\n\nteisipäev, detsember 8\n\nÜkspäev oli nii.Detsember jõudis kätte. Kaunistasidki siis mehed naiskolleegide istekohti. Elfriide oma kaunistasid ja Õrne oma kaunistasid ja. Korrespondendi tehnilise käpardluse tõttu kahjuks pilte ei näe. Aga uskuge, et nii see on. Õrne töökoht sai karda ja tulukesi ja lipsukesi ja laual oleva lille ja monitori külge lisati nodi. Elfriide tool ehiti karraga ja laud tehti muidu jõuluseks.Armiine käis kolleegide juures asju ajamas ja tõdes Õrne laua kohta:"Päris kole. "Boss seepeale:"Ei ole! "ja viitab Elfriide istekohale "vat see on päris kole. "Armine:"Oi,seda ei näinud, on jah. "Maurits rõõmsalt:"Jah, sellesmõttes võib ju öelda, et Õrne oma on täitsa nitševoo."\n\nOn nõupidamiste ruumis on koosolek, mis on oma planeeritud ajast kõvasti üle läinud. Ruumi ukesst kiikavad aeg-ajalt sisse ärevad näod. Keegi kommenteerib, et tahetakse jõulunäidendi proovi tegema hakata.Koosoleku lõppedes suundub rahvas tagasi tööpostile ja jagab mõtteid.Kalmer:"Kultuurne värk. Käivad siin laulukoorimas ja nüüd teevad näidendit. "Elfriide rõõmsalt:"Jah, kultuurimaja noh!"\n\nreede, november 27\n\nBossil ja teistel headel inimestel, kes jagavad Õrnega ühist tööruumi, on aeg-ajalt hobiks Õrne monitori ehtida erinevate dekoratsioonidega. Jõulude kanti kindlasti ka koleläikiva karraga ja laua külge panna ka tulukesed. Lähenemas on jõulukuu ja Õrne on puhkamas. Oleks ju soodus aeg tükk ära ...
#  Text(text='Frukti Koer (0)\n\nTegu on tavalise mänguga, kus sa oll oled pulgaga ja pall tuleb selle peale ja põrkub ainult et palli asemel on koer ja pulkade asemel puuviljad.'),
#  Text(text='Eriti terav elamus.\n\nKui koosolek ära lõppes, oli õues juba pime ja tipptund täie vungiga käima läinud. Kodutee osutus tõelisteks tuleristseteks. Erksalt illumineeritud rekkasid oli kogu vastassuund täis ja need pimestasid nõnda, et eesõitja tagatulesid oli väga raske või kohati ka võimatu märgata. Üks kaubaauto oli Suur-Sõjamäel kaotanud mõistuse või midagi, ning parkis hädatulede plinkides seal kuhu ta surnud oli, miska need rekkad, kes ei mallanud oma raja takistuse taga oodata, võtsid jõuga vastassuuna raja enda valdusse. Hundiseadused. Manööverdasin teepeenrale ja pääsesin kuidagi siiski mööda. Edasi oli püsivalt jube kuni ringteelt lõpuks Saku peale alla keerasin. Kui päevavalges suuri autosid nõndaväga ei märka (kui just mõni neist kahe meetri kaugusel tagumikus ei sõida), siis pimedas ja nii massilisel hulgal (katkematu rekkarong terve tee) on nad tõeline nuhtlus. Just pimestamise koha pealt. Väikeautol on tema kaks tuld ja aamen, kuid peaaegu iga kaubaauto on terve sihverplaadi ulatuses tulesid täis riputatud ja särab nagu juudi jõulupuu. Kogemus muidugi omaette, kuid pimedas ma vabatahtlikult enam Tallinna ringteed ei kasuta.\n\nJah. Ja nüüd kujuta ette, et ma sõitsin igal hommikul selles ringtee rekkarongis 60 km Lasnamäele tööle ja õhtul sama teed tagasi. 120 km pimedas, 5 päeva nädalas, kaheksa aastat järjest kõik talvekuud. Pole ime, et ma absoluutselt enam pimedas sõita ei taha.\n\nMäletan seda aega, lausa oli tahtmine silmad kinni panna kui pimedas kohutavalt suurte valgusejugadega rekkad rivis vastu sõitsid, lohutuseks, et sellega harjub ruttu, peaasi et sõitmistesse vahet ei jäta, edu!\n\nÕnneks on veel teine tee linna kaudu, läksin eile juba sealt. Linna kaudu on teistmoodi kole, aga ainult mõned kohad, mitte püsivalt nagu pimedal maanteel. :)\n\nEga mullegi ei meeldi pimedas ja eriti vihmamärjas sõita, eriti häirib see prillikandjaid, sest kõik läigib meeletult... Nõks, mida kasutan, et vastutulijad ei pimestaks - proovin sel ajal vaadata pisut paremale tee peale, st vastutulijat näha ainult silmanurgast, siis ei pimesta nii hullult. Soovitan katsetada. Ja linnas liigeldes võid ka pimedal ajal kasutada päikesevarju, siis ei pimesta ega sega sind tänavalaternate tuled.\n\nOi, ma mõistan sind nii hästi! See enesetunne selle kõige keskel... sellepärast ma autot ei juhigi, kui vähegi õnnestub see Oti kaela lükata. Ükskord tulin novembri pimedas ja vihmaga Viljandist Haapsallu (mis ei anna Tln ringteele lähedalegi) ja siis oli mul ka kohale jõudes selline närvivapustus, et virutas kõrge palaviku üles.Nii et minu jaoks on auto juhtimine üks kohutavalt hirmus asi. Eriti pimedas.\n\nJah, kusjuures pimedasõidu juures on mind isegi tühjade teede puhul kohutavalt häirinud ka see vilunud juhi pisut fatalistlik lähenemine...ta põrutab pimedal maanteel sajaga kui nähtavus on...noh, nagu ta on, sisuliselt sõidad ju nagu kotti. Sõna-sõnalt pimesi. Ja kust ma tean, et teel pole telliseid, siile, rebaseid, sigu...? Ei teagi. Lihtsalt usun, et ei ole. Või, noh...mitte eriti...:)')]

# %%
train_laused[0]
# Out:
# 'Tallinna linn algatab Paldiski maantee ääres Hotell Tallinna kõrval asuva suure vundamendiaugu ja tühermaa detailplaneeringu koostamise, ehitustööde alustamist takistavad aga ala segased omandisuhted.'

# %%
# Dataseti loomine dataloaderi jaoks
class Dataset(torch.utils.data.Dataset):
    def __init__(self, encodings):
        self.encodings = encodings
    def __len__(self):
        return self.encodings["input_ids"].shape[0]
    def __getitem__(self, i):
        return {key: tensor[i] for key, tensor in self.encodings.items()}

# %%
# Maskimine ja labelid
def mlm(tensor):
    labels = tensor.detach().clone()
    rand = torch.rand(tensor[:, :, 0].shape)
    mask_arr = (rand < 0.15) * (tensor[:, :, 0] > 5)
    for i in range(tensor[:, :, 0].shape[0]):
        selection = torch.flatten(mask_arr[i].nonzero()).tolist()
        selection_masked = torch.where(mask_arr[i] == 0)[0].tolist()
        tensor[i, selection] = 4 # [MASK] tokeni ID mõlemas vocabis
        labels[i, selection_masked] = -100 # Et mudel arvutaks lossi ainult masked tokenite pealt
        
    return tensor, labels

# %%
# %%time
# Andmestiku ettevalmistamine treenimiseks või mudelis kasutamiseks
def prepare_data(data):
    input_ids = []
    mask = []
    labels = []
    
    sample = tokenizer(data, max_length = 8, padding = "max_length", truncation = True, return_tensors = "pt")
    new_ids, new_labels = mlm(sample.input_ids.detach().clone())
    input_ids.append(new_ids)
    mask.append(sample.attention_mask)
    labels.append(new_labels)
    
    input_ids = torch.cat(input_ids)
    mask = torch.cat(mask)
    labels = torch.cat(labels)
    
    encodings = {
    "input_ids" : input_ids,
    "attention_mask" : mask,
    "label_ids" : labels
    }
    
    dataset = Dataset(encodings)
    return dataset


# Dataloaderi loomine mudeli treenimiseks
train_dataset = prepare_data(train_laused)
val_dataset = prepare_data(val_laused)
test_dataset = prepare_data(test_laused)
# Out:
# CPU times: total: 35.6 s
# Wall time: 35.7 s

# %%
train_dataset[0]
# Out:
# {'input_ids': tensor([[    2,     2],
#          [13226,     1],
#          [  183,    34],
#          [ 1545,    53],
#          [    1,     1],
#          [    4,     4],
#          [ 1465,     1],
#          [    3,     3]]),
#  'attention_mask': tensor([1, 1, 1, 1, 1, 1, 1, 1]),
#  'label_ids': tensor([[-100, -100],
#          [-100, -100],
#          [-100, -100],
#          [-100, -100],
#          [-100, -100],
#          [1324,   30],
#          [-100, -100],
#          [-100, -100]])}

# %%
from sklearn.metrics import accuracy_score
def compute_metrics(p):
    pred, labels = p
    
    indeksid = np.where(labels[:, :, 0].flatten() != -100)[0]
    
    labels_lemma = labels[:, :, 0].flatten()[indeksid]
    labels_vorm = labels[:, :, 1].flatten()[indeksid]

    pred_lemma = np.take(np.argmax(pred[0], axis = 2).flatten(), indeksid)
    pred_vorm = np.take(np.argmax(pred[1], axis = 2).flatten(), indeksid)

    accuracy_lemma = accuracy_score(y_true=labels_lemma, y_pred=pred_lemma)
    accuracy_vorm = accuracy_score(y_true=labels_vorm, y_pred=pred_vorm)

    return {"accuracy_lemma": accuracy_lemma, "accuracy_vorm": accuracy_vorm}

# %%
# %%time
# Mudeli treenimine

config = BertConfig(
    vocab_size = tokenizer.vocab_size,
    vocab_size_form = tokenizer.vocab_size_form,
    tie_word_embeddings = False
)

model = BertForMaskedLM(config)

training_args = TrainingArguments(
    output_dir='./train_results',
    per_device_train_batch_size=32,
    max_steps=100,
    learning_rate=1e-4,
    logging_steps=50,
    warmup_steps=10,
    save_steps=50,
    logging_dir='./train_logs',
)

trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=train_dataset,
    eval_dataset=val_dataset,
    compute_metrics=compute_metrics
)

trainer.train()
# Out:
# PyTorch: setting up devices
# The default value for the training argument `--report_to` will change in v5 (from all installed integrations to none). In v5, you will need to use `--report_to all` to get the same behavior as now. You should start updating your code and make this info disappear :-).
# max_steps is given, it will override any value given in num_train_epochs
# ***** Running training *****
#   Num examples = 6246
#   Num Epochs = 1
#   Instantaneous batch size per device = 32
#   Total train batch size (w. parallel, distributed & accumulation) = 32
#   Gradient Accumulation steps = 1
#   Total optimization steps = 100
#   Number of trainable parameters = 166687180
#     <div>
#
#       <progress value='100' max='100' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [100/100 04:49, Epoch 0/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>50</td>
#       <td>13.109300</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>11.830700</td>
#     </tr>
#   </tbody>
# </table><p>
# Saving model checkpoint to ./train_results\checkpoint-50
# Configuration saved in ./train_results\checkpoint-50\config.json
# Model weights saved in ./train_results\checkpoint-50\pytorch_model.bin
# Saving model checkpoint to ./train_results\checkpoint-100
# Configuration saved in ./train_results\checkpoint-100\config.json
# Model weights saved in ./train_results\checkpoint-100\pytorch_model.bin
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
# CPU times: total: 34min 2s
# Wall time: 4min 54s
# TrainOutput(global_step=100, training_loss=12.470031127929687, metrics={'train_runtime': 292.0066, 'train_samples_per_second': 10.959, 'train_steps_per_second': 0.342, 'total_flos': 39074543616000.0, 'train_loss': 12.470031127929687, 'epoch': 0.51})

# %%
dataloader_test = torch.utils.data.DataLoader(train_dataset, batch_size = 16)
kokku_labelid_vorm = np.array([-1])
kokku_labelid_lemma = np.array([-1])
kokku_ennustused_vorm = np.array([-1])
kokku_ennustused_lemma = np.array([-1])
loop = tqdm(dataloader_test, leave = True)

for batch in loop:
    input_ids = batch["input_ids"]
    labels = batch["label_ids"]
    
    output_lemma, output_vorm = model(input_ids).logits
    
    indeksid = np.where(input_ids[:, :, 0].flatten() == 4)
    labels_vorm = labels[:, :, 1].flatten()[indeksid].detach().numpy()
    labels_lemma = labels[:, :, 0].flatten()[indeksid].detach().numpy()
    ennustused_vorm = np.argmax(output_vorm.flatten(end_dim = 1)[indeksid].detach().numpy(), axis = 1)
    ennustused_lemma = np.argmax(output_lemma.flatten(end_dim = 1)[indeksid].detach().numpy(), axis = 1)
    
    kokku_labelid_vorm = np.concatenate((kokku_labelid_vorm, labels_vorm))
    kokku_labelid_lemma = np.concatenate((kokku_labelid_lemma, labels_lemma))
    
    kokku_ennustused_vorm = np.concatenate((kokku_ennustused_vorm, ennustused_vorm))
    kokku_ennustused_lemma = np.concatenate((kokku_ennustused_lemma, ennustused_lemma))
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 391/391 [02:08<00:00,  3.04it/s]

# %%
kokku_labelid_vorm
kokku_labelid_lemma
# Out:
# array([  -1, 1324,   77, ..., 4915,  143,   51], dtype=int64)

# %%
kokku_ennustused_vorm
kokku_ennustused_lemma
# Out:
# array([-1,  7,  7, ...,  7,  7,  7], dtype=int64)

# %%
kokku_labelid_vorm == kokku_ennustused_vorm
kokku_labelid_lemma == kokku_ennustused_lemma
# Out:
# array([ True, False, False, ..., False, False, False])

# %%
sum(kokku_labelid_vorm == kokku_ennustused_vorm)/len(kokku_labelid_vorm)
sum(kokku_labelid_lemma == kokku_ennustused_lemma)/len(kokku_labelid_lemma)
# Out:
# 0.07107790821771612
